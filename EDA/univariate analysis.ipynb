# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import os 
data  = pd.read_csv(os.path.join("C://codes//data//titanic//train.csv"))
data = data.drop(columns=['Name','Ticket','Cabin'])

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S
# 5            6         0       3    male   NaN      0      0   8.4583        Q
# 6            7         0       1    male  54.0      0      0  51.8625        S
# 7            8         0       3    male   2.0      3      1  21.0750        S
# 8            9         1       3  female  27.0      0      2  11.1333        S
# 9           10         1       2  female  14.0      1      0  30.0708        C

# %% [markdown]
# ### CountPlot

# %%
data['Survived'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
data['Pclass'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Pie Chart

# %%
data['Survived'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <AxesSubplot: ylabel='Survived'>

# %%
data['Sex'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <AxesSubplot: ylabel='Sex'>

# %% [markdown]
# ### Histogram

# %%
plt.hist(data.Age,bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ### DistpLOT

# %%
sns.displot(data['Age'])

# %%
sns.displot(data['Pclass'])

# %% [markdown]
# ### BoxPlot

# %%
sns.boxplot(data['Fare'])
# Out:
# <AxesSubplot: >

# %%
## Check skewness 
data['Age'].skew() # positive means rightly skewed and negative means left skewed
# Out:
# 0.38910778230082704
